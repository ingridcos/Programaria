# %% [markdown]
# <a href="https://colab.research.google.com/github/ingridcos/Programaria/blob/main/analise_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #INTRODUÇÃO
#
# ## 📌 Objetivo do projeto
#
# Este projeto tem como objetivo principal duas frentes:
#
# 1. **Aprendizado e prática de análise de dados** utilizando Python e bibliotecas como:
#
#    * Pandas
#    * Matplotlib
#    * Seaborn
#
# 2. **Extração de insights sobre o mercado de trabalho em TI**, identificando padrões, tendências e correlações nos dados coletados.
#
# ## 📊 Escopo da análise
#
# Além de explorar aspectos gerais do mercado de tecnologia, o projeto também aborda:
#
# * Salários na área de TI
# * Níveis de escolaridade
# * Tecnologias mais utilizadas
#
# ## 🌍 Foco em diversidade
#
# Um ponto importante da análise é o estudo de diversidade no setor de tecnologia, com investigação sobre:
#
# * Representatividade de gênero
# * Representatividade racial
#
# ## 🚀 Ferramentas utilizadas
#
# * Python
# * Pandas
# * Matplotlib
# * Seaborn
# * Jupyter Notebook / Google Colab
#
# ## 🧠 Proposta do projeto
#
# A ideia é transformar dados brutos em informações relevantes, permitindo compreender melhor o cenário do mercado de tecnologia e suas desigualdades.
#
# ## 📚 Conteúdo do módulo
#
# Durante este módulo, aprendemos e aplicamos conceitos fundamentais de estatística e análise de dados:
#
# * 📊 Conceitos principais de estatística aplicados a bases de dados reais
# * 🧹 Tratamento de valores faltantes e outliers
#
#   * Identificação e correção de dados incompletos e atípicos
#   * Garantia de análises mais precisas e robustas
# * 📈 Intervalo de confiança e distribuição amostral
#
#   * Inferência estatística baseada em amostras
# * 🧠 Feature engineering
#
#   * Criação de novas variáveis para enriquecer a análise
#   * Transformação de dados brutos em informações mais úteis
# * 🔗 Análise de correlação
#
#   * Identificação de relações entre variáveis
#   * Descoberta de padrões e insights importantes
#
# ## ✨ Conclusão
#
# Vamos começar nossa jornada de exploração dos dados e descobertas!

# %% [markdown]
# ##IMPORTAÇÕES

# %%
# Bibliotecas padrão de análise de dados
import numpy as np
import pandas as pd

# Visualização
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Estatística
from scipy import stats
from scipy.stats import chi2_contingency

# Google Drive (Colab)
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
dados = pd.read_excel('/content/drive/MyDrive/Programaria/Módulo 3 e 4/planilha_modulo3.xlsx')

# %%
dados
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# ...          ...                               ...    ...         ...
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4269        4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
dados.head()
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
# ...

# %%
dados.tail()
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4269        4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 4266  Masculino         Branca  Não
# 4267   Feminino         Branca  Não
# 4268  Masculino         Branca  Não
# 4269  Masculino         Branca  Não
# 4270  Masculino         Branca  Não
#
#                    EXPERIENCIA_PROFISSIONAL_PREJUDICADA ASPECTOS_PREJUDICADOS  \
# 4266                                                NaN                   NaN
# 4267  Não acredito que minha experiência profissiona...                   NaN
# 4268                                                NaN                   NaN
# ...

# %%
dados.shape
# Out:
# (4271, 28)

# %%
len(dados)
# Out:
# 4271

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %%
dados.describe()
# Out:
#         Unnamed: 0        IDADE  MUDOU DE ESTADO?      GESTOR?        SALARIO
# count  4271.000000  4197.000000       4171.000000  3694.000000    3694.000000
# mean   2135.000000    31.169168          0.806281     0.193016   10969.266919
# std    1233.075829     6.902803          0.395258     0.394719   19419.753189
# min       0.000000    18.000000          0.000000     0.000000      35.000000
# 25%    1067.500000    26.000000          1.000000     0.000000    4269.500000
# 50%    2135.000000    30.000000          1.000000     0.000000    7625.500000
# 75%    3202.500000    35.000000          1.000000     0.000000   12778.500000
# max    4270.000000    54.000000          1.000000     1.000000  485191.000000

# %% [markdown]
# #Repetindo Análise do Excel

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %% [markdown]
# Dados: Gênero

# %%
dados['GENERO']
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %% [markdown]
# Dados: Genero Feminino

# %%
dados[dados['GENERO']=='Feminino']
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# ...

# %% [markdown]
# Dados: Genero Masculino

# %%
dados[dados['GENERO']!='Masculino']
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 9              9  zxc3d314cn1c2ovmzxc34ha7nkw1na3j    NaN         55+
# 10            10  zwy34gktg0tfjq2ttjvazwy34gg3g49i   25.0       25-29
# ...          ...                               ...    ...         ...
# 4248        4248  070o4zayoboztox764qu070o4zafbqrd   27.0       25-29
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4259        4259  03n2lq8st9zobnowu3w03n2lqi0flz2w   28.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#         GENERO COR/RACA/ETNIA  PCD  \
# 4     Feminino         Branca  Não
# 5     Feminino          Parda  Não
# ...

# %% [markdown]
# Dados: Genero Prefiro Não Informar

# %%
dados[dados['GENERO'].str.contains('não', na=False)]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 562          562  vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528        1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913        1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925        1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554        2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090        3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357        3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493        3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610        3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171        4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200        4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227        4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
# ...

# %% [markdown]
# Dados: Idade > ou = a 30 anos

# %%
dados[dados['IDADE']>=30]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# ...          ...                               ...    ...         ...
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
# 4264        4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %% [markdown]
# Dados = Idade > que 30 anos e do genero feminino

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]
#
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 14            14  zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39
# 23            23  zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49
# ...          ...                               ...    ...         ...
# 4214        4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44
# 4221        4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34
# 4240        4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39
# 4247        4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
#
#         GENERO COR/RACA/ETNIA                   PCD  \
# 4     Feminino         Branca                   Não
# ...

# %% [markdown]
# Dados: Etnia Amarela

# %%
dados[dados['COR/RACA/ETNIA'] == 'Amarela']
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 13            13  zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24
# 85            85  zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29
# 97            97  zbukfwxvpwlk6loglm0zbukfwx6bvyb6   40.0       40-44
# 107          107  z9toybzbja7n6xjjbz9f8hmofrry69tg   44.0       40-44
# 159          159  ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39
# ...          ...                               ...    ...         ...
# 4176        4176  0qpa64gqpieg60xpygnajt70qpa64g1a   27.0       25-29
# 4207        4207  0ibb8fj9qrwpswfqiil0ibb89e3e4hz3   30.0       30-34
# 4210        4210  0hbwm1d1wz739r40hbwm1df6ky5kn4ap   43.0       40-44
# 4257        4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 13    Masculino        Amarela  Não
# 85     Feminino        Amarela  Não
# ...

# %% [markdown]
# Dados: Idade < que 40 anos

# %%
dados[dados['IDADE'] < 40]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 6              6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21
# ...          ...                               ...    ...         ...
# 4265        4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29
# 4266        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29
# 4267        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp   30.0       30-34
# 4268        4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29
# 4270        4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %% [markdown]
# Dados: Etnia Amarela e que tenham < de 40 anos

# %%
dados[(dados['COR/RACA/ETNIA'] == 'Amarela') & (dados['IDADE'] < 40)]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 13            13  zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24
# 85            85  zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29
# 159          159  ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39
# 170          170  yri3z491ejizlpj9ylu2k3jyri3z4915   34.0       30-34
# 195          195  yjbpxmkqz5yidh5oszyjbpxmkgcb1zd9   32.0       30-34
# ...          ...                               ...    ...         ...
# 3947        3947  2tnsh0gxdu3aq4z2d2tnsh0hk15brx7q   31.0       30-34
# 4058        4058  1t3ndwx8j50k0bz1t3ndwxdpwyg17c2k   27.0       25-29
# 4176        4176  0qpa64gqpieg60xpygnajt70qpa64g1a   27.0       25-29
# 4207        4207  0ibb8fj9qrwpswfqiil0ibb89e3e4hz3   30.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 13    Masculino        Amarela  Não
# 85     Feminino        Amarela  Não
# ...

# %% [markdown]
# Dados: Etnia Amarela que tenham < de 40 anos e que seja do genero feminino

# %%
dados[
    (dados['COR/RACA/ETNIA'] == 'Amarela') &
    (dados['IDADE'] < 40) &
    (dados['GENERO'] == 'Feminino')
]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 85            85  zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29
# 159          159  ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39
# 281          281  xtakkr70pi8j3a1yjiogxaxtakk9wqo8   24.0       22-24
# 333          333  xh5q34spt0f5z2zro9xh5qufedvfm8z8   36.0       35-39
# 557          557  vkrq4f01p6c8kwoudb7658gvkrq4funw   27.0       25-29
# 581          581  vaw950izv5zvkx3wu7a1vaw950m97zvm   35.0       35-39
# 734          734  tzswd6jiska94g1kktzswd6j5xloqyoy   32.0       30-34
# 748          748  tvwpafypblqxk95yy9tvwpafyywzv4ym   28.0       25-29
# 927          927  sdr31f85cq9nazyly66x3sdr3kw65y7t   25.0       25-29
# 950          950  s61b599i2ow0ldgs6138n1taubo60hm8   36.0       35-39
# 961          961  s0pjhm8ly5lddu6qs0est2cr1u7vgq10   29.0       25-29
# 1141        1141  qmb7sr5as3ezqmb3gqyl342q6inua31u   29.0       25-29
# ...

# %% [markdown]
# Agrupamento dos gêneros usando o nunique

# %%
dados.groupby('GENERO')['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %% [markdown]
# Contagem dos generos

# %%
dados['GENERO'].value_counts(dropna=False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %% [markdown]
# Filtro com contagem por NÍVEL, apenas pessoas com IDADE > 30

# %%
dados[dados['IDADE'] > 30]['NIVEL'].value_counts()
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %% [markdown]
# Filtro com dois filtros: IDADE > 30 e GENERO == 'Feminino'

# %%
dados[(dados['IDADE'] > 30) & (dados['GENERO'] == 'Feminino')]['NIVEL'].value_counts()
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %% [markdown]
# Pessoa gestora por genero

# %%
pd.pivot_table(dados, values=['ID'], index=['GENERO'], columns=['GESTOR?'], aggfunc='count')
# Out:
#                         ID
# GESTOR?                0.0  1.0
# GENERO
# Feminino               754  132
# Masculino             2212  578
# Prefiro não informar     9    2

# %% [markdown]
# #Estatística Básica

# %% [markdown]
# Média de Idade

# %%
dados['IDADE'].mean()
# Out:
# np.float64(31.169168453657374)

# %% [markdown]
# Mediana de Idade

# %%
dados['IDADE'].median()
# Out:
# 30.0

# %% [markdown]
# Moda - IDADE QUE MAIS APARECE

# %%
dados['IDADE'].mode()
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %% [markdown]
# Desvio Padrão

# %%
dados['IDADE'].std()
# Out:
# 6.902802832143141

# %% [markdown]
# Idade Mínima

# %%
dados['IDADE'].min()
# Out:
# 18.0

# %% [markdown]
# Idade Máxima

# %%
dados['IDADE'].max()
# Out:
# 54.0

# %% [markdown]
# Média de Idade do Gênero Feminino

# %%
dados[dados['GENERO'] == 'Feminino']['IDADE'].mean()
# Out:
# np.float64(31.318051575931232)

# %% [markdown]
# Média de Idade do Gênero Masculino

# %%
dados[dados['GENERO'] == 'Masculino']['IDADE'].mean()
# Out:
# np.float64(31.147876077930373)

# %% [markdown]
# Média Salarial do Gênero Feminino

# %%
dados[dados['GENERO']=='Feminino']['SALARIO'].mean()
# Out:
# np.float64(8673.22460496614)

# %% [markdown]
# Média Salarial do Gênero Masculino

# %%
dados[dados['GENERO']=='Masculino']['SALARIO'].mean()
# Out:
# np.float64(11724.552688172043)

# %% [markdown]
# #Valores faltantes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %% [markdown]
# **Trabalhando coluna de gênero**

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'].fillna('Prefiro não informar')
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %% [markdown]
# Juntando os nulos com prefiro não informar

# %%
dados['GENERO'] = dados['GENERO'].fillna('Prefiro não informar')

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# **Trabalhando colunas de idade**

# %%
dados['IDADE'].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %% [markdown]
#  Média das idades 17-21

# %%
dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()
# Out:
# np.float64(20.205479452054796)

# %%
media_17_21 = dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()

# %%
dados.loc[(dados['FAIXA IDADE']=='17-21') & (dados['IDADE'].isnull()), 'IDADE']
# Out:
# 1925   NaN
# 2393   NaN
# 3367   NaN
# 4086   NaN
# 4177   NaN
# 4269   NaN
# Name: IDADE, dtype: float64

# %% [markdown]
# Substitua os valores adicionando = media_17_21

# %%
dados.loc[(dados['FAIXA IDADE']=='17-21') & (dados['IDADE'].isnull()), 'IDADE'] = media_17_21

# %% [markdown]
# Conerindo a substituição 17-21

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+    68
# Name: count, dtype: int64

# %% [markdown]
# +55 de idade

# %%
dados[dados['FAIXA IDADE']=='55+']['IDADE']
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %% [markdown]
# Nível dos +55

# %%
dados[dados['FAIXA IDADE']=='55+']['NIVEL']
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %% [markdown]
# Média da coluna de idade 55+

# %%
media_geral = dados['IDADE'].mean()
media_geral
# Out:
# np.float64(31.153517220250375)

# %% [markdown]
# Localize os valores nulos para substituí-los pela média geral

# %%
dados.loc[(dados['FAIXA IDADE']=='55+') & (dados['IDADE'].isnull()), 'IDADE']
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %% [markdown]
# Substitua +55 pela média_geral

# %%
dados.loc[(dados['FAIXA IDADE']=='55+') & (dados['IDADE'].isnull()), 'IDADE'] = media_geral

# %% [markdown]
# Conferindo a substituição dos +55

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# **Tratando a coluna SALARIO**

# %%
dados[dados['SALARIO'].isnull()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 12            12  zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34
# 28            28  ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24
# 34            34  zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24
# 39            39  zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34
# 63            63  zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29
# ...          ...                               ...    ...         ...
# 4242        4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29
# 4252        4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 12    Masculino         Branca  Não
# 28     Feminino          Parda  Não
# ...

# %%
dados[dados['SALARIO'].isnull()]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
mediana_salario = dados['SALARIO'].median()
mediana_salario
# Out:
# 7625.5

# %%
dados.loc[dados['SALARIO'].isnull(), 'SALARIO'] = mediana_salario

# %% [markdown]
# #Valores discrepantes - Outliers

# %% [markdown]
#  Outliers da coluna salário

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a19541b5460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a19541b51f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a1954c03f20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a19541b5820>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a19541b5ac0>],
#  'means': []}

# %% [markdown]
# Regra dos quartis

# %%
Q1 = dados['SALARIO'].quantile(0.25)
Q1
# Out:
# np.float64(4751.5)

# %%
Q3 = dados['SALARIO'].quantile(0.75)
Q3
# Out:
# np.float64(11794.5)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(7043.0)

# %% [markdown]
# Limites

# %%
limite_superior = Q3 + (1.5*IQR)
limite_superior
# Out:
# np.float64(22359.0)

# %%
limite_inferior = Q1 - (1.5*IQR)
limite_inferior
# Out:
# np.float64(-5813.0)

# %% [markdown]
# Verificando a quantidade de pessoas por faixa salarial

# %%
dados['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %% [markdown]
# Calculando a média e o desvio padrão

# %%
media_salario = dados['SALARIO'].mean()
media_salario
# Out:
# np.float64(10517.53348162023)

# %%
desvio_salario = dados['SALARIO'].std()
desvio_salario
# Out:
# 18096.210989118474

# %% [markdown]
# Calculando o limite

# %%
limite_superior = media_salario + (3*desvio_salario)
limite_superior
# Out:
# np.float64(64806.16644897565)

# %% [markdown]
# Verificando a faixa salarial

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês              19
# de R$ 30.001/mês a R$ 40.000/mês     3
# Name: count, dtype: int64

# %% [markdown]
# Filtrar determinados médias salariais e desconsiderar os outliers

# %%
media_30_40 = dados[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']<limite_superior)]['SALARIO'].mean()

# %% [markdown]
# Localizando os outliers

# %%
dados.loc[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']>limite_superior), 'SALARIO'] = media_30_40

# %% [markdown]
# Confirmando se deu certo

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %% [markdown]
# Média de salários acima de R$ 40.000

# %%
media_40 = dados[(dados['FAIXA SALARIAL']=='Acima de R$ 40.001/mês') & (dados['SALARIO']<limite_superior)]['SALARIO'].mean()
media_40
# Out:
# np.float64(53127.846153846156)

# %%
dados.loc[(dados['FAIXA SALARIAL']=='Acima de R$ 40.001/mês') & (dados['SALARIO']>limite_superior), 'SALARIO'] = media_40

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# RESULTADO

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a19540fe990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7a19540ff110>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7a19541652b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a19540ff800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a19540ffc50>],
#  'means': []}

# %% [markdown]
# #Intervalo de confiança e distribuição amostral

# %%
salarios = dados['SALARIO']
salarios
# Out:
# 0       11194.0
# 1        4695.0
# 2       14202.0
# 3       15463.0
# 4        7733.0
#          ...
# 4266     4329.0
# 4267     3758.0
# 4268    19607.0
# 4269      989.0
# 4270     3079.0
# Name: SALARIO, Length: 4271, dtype: float64

# %% [markdown]
# Média Amostral dos Salários

# %%
media_amostral = np.mean(salarios)
media_amostral
# Out:
# np.float64(9904.390109813306)

# %% [markdown]
# Desvio Padrão Amostral

# %%
desvio_amostral = np.std(salarios)
desvio_amostral
# Out:
# 8306.104872579343

# %% [markdown]
# Nível de Confiança de 95%

# %%
nivel_confianca = 0.95

# %%
tamanho_amostra = len(salarios)
tamanho_amostra
# Out:
# 4271

# %% [markdown]
# Erro Padrão da Amostra

# %%
erro_padrao = stats.sem(salarios)
erro_padrao
# Out:
# np.float64(127.11109872023638)

# %% [markdown]
# Intervalo de Confiança da Média Salarial da Área de Tecnologia

# %%
intervalo_confianca = stats.t.interval(nivel_confianca, tamanho_amostra-1, loc=media_amostral, scale=erro_padrao)
intervalo_confianca
# Out:
# (np.float64(9655.186295869078), np.float64(10153.593923757535))

# %% [markdown]
# Nosso intervalo de confiança calculado foi de 9618 a 10105. O intervalo de confiança de 95% entre 9618 e 10105 significa que estamos 95% confiantes de que a verdadeira média salarial da população está entre 9618 e 10105. Em outras palavras, se coletássemos muitas amostras diferentes e calculássemos intervalos de confiança para cada uma, esperamos que 95% desses intervalos contenham a verdadeira média salarial.

# %% [markdown]
# #Featuring Engineering

# %% [markdown]
# CONDIÇÃO: PESSOA GESTORA
#
# Função: Preencher Nível

# %%
def preencher_nivel(gestor,nivel):
  if gestor==1:
   return "Pessoa Gestora"
  else:
    return nivel

# %%
dados['NOVO_NIVEL'] = dados.apply(lambda x: preencher_nivel(x['GESTOR?'], x['NIVEL']), axis=1)

# %% [markdown]
# Criamos a coluna "NOVO_NIVEL"

# %%
dados['NOVO_NIVEL']
# Out:
# 0               Júnior
# 1       Pessoa Gestora
# 2                Pleno
# 3               Sênior
# 4                Pleno
#              ...
# 4266             Pleno
# 4267             Pleno
# 4268    Pessoa Gestora
# 4269            Júnior
# 4270            Júnior
# Name: NOVO_NIVEL, Length: 4271, dtype: object

# %%
dados['NOVO_NIVEL'].value_counts()
# Out:
# NOVO_NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados['NIVEL']
# Out:
# 0       Júnior
# 1          NaN
# 2        Pleno
# 3       Sênior
# 4        Pleno
#          ...
# 4266     Pleno
# 4267     Pleno
# 4268       NaN
# 4269    Júnior
# 4270    Júnior
# Name: NIVEL, Length: 4271, dtype: object

# %%
dados = pd.get_dummies(dados, columns=['NIVEL'])

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %% [markdown]
# Criação da Coluna "GERAÇÃO

# %%
def determinar_geracao(idade):
  if 39<idade<=58:
    return "Geração X"
  elif 29< idade <=39:
    return "Millenial"
  elif 13< idade<=29:
    return "Geração Z"
  else:
    return "Outra geração"

# %%
dados['GERACAO'] = dados['IDADE'].apply(determinar_geracao)

# %%
dados['GERACAO']
# Out:
# 0       Millenial
# 1       Millenial
# 2       Geração X
# 3       Geração Z
# 4       Geração X
#           ...
# 4266    Geração Z
# 4267    Millenial
# 4268    Geração Z
# 4269    Geração Z
# 4270    Geração Z
# Name: GERACAO, Length: 4271, dtype: object

# %%
dados['GERACAO'].value_counts()
# Out:
# GERACAO
# Geração Z    1999
# Millenial    1761
# Geração X     511
# Name: count, dtype: int64

# %% [markdown]
# #TABELA - FEATURING ENGINEERING - PARTE 2

# %%
dados2 = pd.read_excel ('/content/drive/MyDrive/Programaria/Módulo 3 e 4/Planilha_Aula_parte2.xlsx')

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
# ...

# %% [markdown]
# Juntando os dados em comum(merge)

# %%
dados.merge(dados2, on='ID', how='left')
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.000000       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd  32.000000       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.000000       50-54
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.000000       25-29
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# ...          ...                               ...        ...         ...
# 4268        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp  26.000000       25-29
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34
# 4270        4268  00zw9ks9d40z4u00zz3d20iix65qpli3  29.000000       25-29
# 4271        4269  00xu7yujd7s57emj00xu7y0c3njix3de  20.205479       17-21
# 4272        4270  00lb35llmdsidpa00lb35qcdysnzvhv7  24.000000       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# ...

# %%
dados = dados.merge(dados2, on='ID', how='left')

# %%
dados.head()
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
# ...

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %% [markdown]
# Identificação de Intenção de Mudança de Emprego

# %%
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
dados['EM_BUSCA'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('em busca', case=False)

# %%
dados['EM_BUSCA'].value_counts()
# Out:
# EM_BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %% [markdown]
# Identifique quem está aberto à oportunidades

# %%
dados['ABERTO_OPORTUNIDADES'] = dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('aberto', case=False)

# %%
dados['ABERTO_OPORTUNIDADES'].value_counts()
# Out:
# ABERTO_OPORTUNIDADES
# False    2342
# True     1354
# Name: count, dtype: int64

# %% [markdown]
# #Coluna de ETNIA

# %%
dados['COR/RACA/ETNIA'].value_counts()
# Out:
# COR/RACA/ETNIA
# Branca                  2746
# Parda                   1054
# Preta                    291
# Amarela                  128
# Prefiro não informar      26
# Outra                     17
# Indígena                  11
# Name: count, dtype: int64

# %%
def determinar_etnia(cor):
  if cor == 'Branca':
    return 'Pessoa Branca'
  elif cor == 'Preta':
    return 'Pessoa Preta'
  elif cor == 'Parda':
    return 'Pessoa Parda'
  elif cor == 'Amarela':
    return 'Pessoa Amarela'
  elif cor == 'Indígena':
    return 'Pessoa Indígena'
  elif cor == 'Outra':
    return 'Pessoa de Etnia Não Identificada'
  else:
    return 'Etnia Não Informada'

# %%
dados['ETNIA'] = dados['COR/RACA/ETNIA'].apply(determinar_etnia)

# %%
dados['ETNIA']
# Out:
# 0        Pessoa Parda
# 1        Pessoa Parda
# 2       Pessoa Branca
# 3       Pessoa Branca
# 4       Pessoa Branca
#             ...
# 4268    Pessoa Branca
# 4269    Pessoa Branca
# 4270    Pessoa Branca
# 4271    Pessoa Branca
# 4272    Pessoa Branca
# Name: ETNIA, Length: 4273, dtype: object

# %%
dados['ETNIA'].value_counts()
# Out:
# ETNIA
# Pessoa Branca                       2746
# Pessoa Parda                        1054
# Pessoa Preta                         291
# Pessoa Amarela                       128
# Etnia Não Informada                   26
# Pessoa de Etnia Não Identificada      17
# Pessoa Indígena                       11
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %% [markdown]
# # Correlação: positiva, negativa e coeficiente de Pearson
#
# A correlação nos diz se e como duas variáveis estão relacionadas. Ela é muito usada em análise de dados para entender se mudanças em uma variável estão associadas a mudanças em outra.[web:21][web:22]
#
# ---
#
# ## Tipos de correlação
#
# ### 1. Correlação positiva
#
# A correlação **positiva** ocorre quando duas variáveis aumentam (ou diminuem) juntas.[web:26][web:27]
# Ou seja, quando uma variável cresce, a outra tende a crescer também.
#
# **Exemplo:**
# - Quanto mais um aluno estuda, maior é seu desempenho acadêmico.
# Aqui, horas de estudo ↑ e nota ↑, indicando uma correlação positiva.
#
# ---
#
# ### 2. Correlação negativa
#
# A correlação **negativa** acontece quando uma variável aumenta enquanto a outra diminui.[web:26][web:27]
# Ou seja, quando uma variável cresce, a outra tende a cair.
#
# **Exemplo:**
# - Quanto mais tempo um aluno passa assistindo TV, menor é seu desempenho acadêmico.
# Aqui, tempo de TV ↑ e nota ↓, indicando uma correlação negativa.
#
# ---
#
# ## Coeficiente de correlação de Pearson
#
# A função de correlação mais usada é o **coeficiente de correlação de Pearson**, que varia de **-1 a 1**.[web:22][web:25]
#
# - Valor próximo de **1** → forte correlação positiva
# - Valor próximo de **-1** → forte correlação negativa
# - Valor próximo de **0** → indica que não há relação linear entre as variáveis
#
# Em resumo, o coeficiente mede a força e a direção da relação **linear** entre duas variáveis quantitativas.[web:22][web:24]
#
# ---
#
# ## Exemplo de interpretação
#
# Ao calcular a correlação entre horas de estudo e desempenho acadêmico, um coeficiente de **0,8** indica uma correlação **positiva forte**.
# Isso quer dizer que, em geral, quanto mais o aluno estuda, maior tende a ser sua nota.
#
# ```python
# # Exemplo em Python (pandas)
# dados['HORAS_ESTUDO'].corr(dados['DESEMPENHO'])
# ```

# %% [markdown]
# Correlação entre Idade X Salário

# %%
correlacao_continua = dados['IDADE'].corr(dados['SALARIO'])
correlacao_continua
# Out:
# np.float64(0.2902441968622099)

# %% [markdown]
# 0.29 está mais próximo de zero que de 1. É uma correlação positiva, mas não muito forte.
#
# A idade não é o fator relevante para o salário aumentar.

# %% [markdown]
# # Correlação para variáveis discretas: coeficiente de Cramér
#
# Quando trabalhamos com **variáveis categóricas/discretas** (como gênero, nível, etnia, região), o coeficiente de correlação de Pearson não é o mais adequado.[web:35][web:39]
# Nesses casos, usamos o **coeficiente de Cramér** (também chamado de Cramér's V) para medir a **força de associação** entre duas variáveis categóricas.[web:31][web:35]
#
# ---
#
# ## O que fizemos
#
# Calculamos a correlação entre variáveis **discretas** usando o **coeficiente de Cramér**.
# Para isso, criamos uma função chamada `cramer_coeficiente` que:
#
# 1. Gera uma **tabela cruzada** (tabela de contingência) com `pandas.crosstab`
# 2. Usa a função `chi2_contingency` da biblioteca `scipy.stats` para obter o valor do **qui‑quadrado**
# 3. A partir desse valor, calcula o coeficiente de Cramér.[web:31][web:34]
#
# ---
#
# ## Fórmula (ideia geral)
#
# O coeficiente de Cramér é baseado na estatística do teste qui‑quadrado:
#
# \[
# V = \sqrt{\frac{\chi^2 / N}{\min(k-1, r-1)}}
# \]
#
# - \(\chi^2\): estatística do teste qui‑quadrado
# - \(N\): total de observações (tamanho da amostra)
# - \(k\): número de colunas da tabela
# - \(r\): número de linhas da tabela[web:31][web:39]
#
# O resultado varia de **0 a 1**:
# - **0** → nenhuma associação
# - **1** → associação perfeita
#
# ---
#
# ## Implementação em Python
#
# ```python
# import pandas as pd
# import numpy as np
# from scipy.stats import chi2_contingency
#
# def cramer_coeficiente(x, y):
#     # 1. Tabela cruzada (contingência)
#     tabela = pd.crosstab(x, y)
#
#     # 2. Qui-quadrado com chi2_contingency
#     chi2, p, dof, expected = chi2_contingency(tabela)
#
#     # 3. Cálculo do Cramér (versão básica)
#     n = tabela.to_numpy().sum()
#     min_dim = min(tabela.shape) - 1
#     v = np.sqrt((chi2 / n) / min_dim)
#     return v
# ```
#
# ---
#
# ## Exemplo de uso
#
# ```python
# # Exemplo: associação entre NIVEL e GENERO
# v_cramer = cramer_coeficiente(dados['NIVEL'], dados['GENERO'])
# print(f'Cramér V (NIVEL x GENERO): {v_cramer:.3f}')
# ```
#
# ---
#
# ## Quando usar Cramér
#
# Use o coeficiente de Cramér quando:
#
# - As duas variáveis são **categóricas** (nominais ou ordinais)
# - Você tem uma **tabela de frequências** (contagem) entre duas variáveis
# - Quer medir a **força de associação**, e não apenas fazer o teste de independência do qui‑quadrado.[web:32][web:35]
#
# Ele é ideal para análises de **People Analytics**, como:
# - `NIVEL` × `ETNIA`
# - `GENERO` × `PROMOCAO`
# - `ÁREA` × `RETENÇÃO`

# %% [markdown]
# Correlação entre Educação e Etnia

# %%
def cramer_coeficiente(coluna1, coluna2):
  tabela_cruzada = np.array(pd.crosstab(coluna1, coluna2))
  chi2 = chi2_contingency(tabela_cruzada)[0]
  soma = np.sum(tabela_cruzada)
  mini = min(tabela_cruzada.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
# Out:
# np.float64(0.04499106580480143)

# %%
cramer_coeficiente(dados['ETNIA'], dados['NIVEL DE ENSINO'])
# Out:
# np.float64(0.04499106580480143)

# %% [markdown]
# Com esta correlação, que é bem mais próximo de zero, vale considerar o contexto.
#
# Aplicamos essa função para verificar a relação entre cor/raça/etnia e nível de ensino, obtendo um coeficiente de 0.044, indicando quase nenhuma relação.
#
# Este resultado sugere que, na nossa amostra, etnias diferentes têm níveis de ensino semelhantes, possivelmente devido ao contexto da área de TI, onde a maioria já tem algum tipo de formação.

# %%
tabela_cruzada = pd.crosstab(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# ...

# %%
np.array(tabela_cruzada)
# Out:
# array([[  7,  15,  50,  14,   2,   0,  40],
#        [127, 365, 999, 355,  65,   8, 827],
#        [  0,   2,   4,   2,   0,   0,   3],
#        [  0,   0,   6,   3,   1,   0,   7],
#        [ 50, 178, 333, 113,  33,   3, 344],
#        [  1,   2,  14,   1,   0,   1,   7],
#        [  6,  51, 104,  33,   9,   0,  88]])

# %% [markdown]
# #CorrelaçãoCheck

# %% [markdown]
# Correlação entre Nível de Ensino e Gênero

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
cramer_coeficiente(dados['NIVEL DE ENSINO'], dados['GENERO'])
# Out:
# np.float64(0.076119232802818)

# %% [markdown]
# O coeficiente de Cramér entre Nível de Ensino e Gênero foi de aproximadamente 0,08. Esse valor é muito próximo de zero, o que indica uma associação não muito forte entre as duas variáveis. Em outras palavras, nesta amostra, o gênero das pessoas não está fortemente relacionado ao nível de ensino: homens e mulheres apresentam níveis de escolaridade muito semelhantes.

# %% [markdown]
# Corelação entre Salário e Genero

# %%
cramer_coeficiente(dados['SALARIO'], dados['GENERO'])
# Out:
# np.float64(0.8549117542423437)

# %% [markdown]
# Já a associação entre Salário e Gênero apresentou coeficiente de Cramér de aproximadamente 0,85, o que indica uma associação muito forte entre essas variáveis. Em outras palavras, nesta base de dados, o gênero está fortemente relacionado à faixa salarial, apontando possível desigualdade de remuneração entre homens e mulheres.

# %% [markdown]
# #SALVANDO EM CSV

# %%
dados.to_csv('/content/drive/MyDrive/Programaria/Módulo 3 e 4/analise_dados.csv', index=False)

# %% [markdown]
# #Conectando SQL com Pandas

# %%
import sqlite3

# %%
conexao = sqlite3.connect('/content/drive/MyDrive/Programaria/Modulo 5/status_brasil')

# %%
query = "SELECT * FROM Municipios_Brasileiros WHERE Cidade='Itaquaquecetuba';"
query
# Out:
# "SELECT * FROM Municipios_Brasileiros WHERE Cidade='Itaquaquecetuba';"

# %%
pd.read_sql(query, con=conexao)
# Out:
#             Cidade Estado   Regiao  municipio_ID
# 0  Itaquaquecetuba     SP  Sudeste          5043

# %% [markdown]
# #Conectando com CSV

# %%
dados = pd.read_csv('/content/drive/MyDrive/Programaria/Módulo 3 e 4/analise_dados.csv')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %% [markdown]
# Renda por Estado

# %%
lista_estados = list(dados['UF ONDE MORA'].unique())

# %%
query = '''SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda) FROM Municipios_Brasileiros
        INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID WHERE Municipios_Brasileiros.Estado IN({})
        GROUP BY Municipios_Brasileiros.Estado;'''.format(','.join(['?' for _ in lista_estados]))

# %%
print(query)
# Out:
# SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda) FROM Municipios_Brasileiros
#         INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID WHERE Municipios_Brasileiros.Estado IN(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
#         GROUP BY Municipios_Brasileiros.Estado;

# %%
estados_renda = pd.read_sql(query, con=conexao, params=lista_estados)

# %%
dados.rename(columns ={'UF ONDE MORA': 'Estado'}, inplace=True)

# %%
dados.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'ID',
#  'IDADE',
#  'FAIXA IDADE',
#  'GENERO',
#  'COR/RACA/ETNIA',
#  'PCD',
#  'EXPERIENCIA_PROFISSIONAL_PREJUDICADA',
#  'ASPECTOS_PREJUDICADOS',
#  'VIVE_NO_BRASIL',
#  'ESTADO ONDE MORA',
#  'Estado',
#  'REGIAO ONDE MORA',
#  'MUDOU DE ESTADO?',
#  'REGIAO DE ORIGEM',
#  'NIVEL DE ENSINO',
#  'ÁREA DE FORMAÇÃO',
#  'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?',
#  'SETOR',
#  'NUMERO DE FUNCIONARIOS',
#  'GESTOR?',
#  'CARGO COMO GESTOR',
#  'CARGO ATUAL',
#  'FAIXA SALARIAL',
#  'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#  'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#  'SALARIO',
#  'NOVO_NIVEL',
#  'NIVEL_Júnior',
#  'NIVEL_Pleno',
#  'NIVEL_Sênior',
#  'GERACAO',
#  'Quanto tempo de experiência na área de dados você tem?',
#  'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
dados = dados.merge(estados_renda, on='Estado', how='left')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'Estado', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
correlacao_renda_salario = dados['SALARIO'].corr(dados['AVG(Municipio_Status.renda)'])
correlacao_renda_salario
# Out:
# np.float64(0.12083384881429463)

# %% [markdown]
# Correlação entre Educação e Salário

# %%
query = '''SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.educacao)
           FROM Municipios_Brasileiros
           INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
           WHERE Municipios_Brasileiros.Estado IN({})
           GROUP BY Municipios_Brasileiros.Estado;'''.format(','.join(['?' for _ in lista_estados]))

# %%
educacao_salario = pd.read_sql(query, con=conexao, params=lista_estados)

# %%
dados.merge(educacao_salario, on='Estado', how='left')
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.000000       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd  32.000000       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.000000       50-54
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.000000       25-29
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# ...          ...                               ...        ...         ...
# 4268        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp  26.000000       25-29
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34
# 4270        4268  00zw9ks9d40z4u00zz3d20iix65qpli3  29.000000       25-29
# 4271        4269  00xu7yujd7s57emj00xu7y0c3njix3de  20.205479       17-21
# 4272        4270  00lb35llmdsidpa00lb35qcdysnzvhv7  24.000000       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# ...

# %%
dados = dados.merge(educacao_salario, on='Estado', how='left')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'Estado', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
correlacao_educacao_salario = dados['SALARIO'].corr(dados['AVG(Municipio_Status.educacao)'])
correlacao_educacao_salario
# Out:
# np.float64(0.15558020288268756)

# %% [markdown]
# Análise de Correlação Pearson:
#
# Coeficiente: r = 0.16
#
# Interpretação:
#
# Valor entre 0.1 e 0.3: correlação fraca positiva - CONSIDERE O CONTEXTO.
#
# Direção: Positiva (mais educação → salário ligeiramente maior).
#
# Força: Fraca (explica ~2.5% da variação salarial, r²=0.026).
#
# Conclusão: Educação influencia salário na área de tecnologia, mas não é o principal driver — experiência e habilidades práticas pesam mais.

# %% [markdown]
# Por quê 0.16 é realista pro Brasil? Estudos mostram retornos ~10-12% por ano extra de estudo, mas na tech, certificações/bootcamps superam diploma formal.
#
# Resumo: Fraca positiva (0.16) — educação ajuda, mas skills > diploma na área de tech.

# %% [markdown]
# Correlaçao entre Renda e Educação

# %%
educacao_renda = pd.read_sql(query, con=conexao, params=lista_estados)

# %%
correlacao_educacao_renda = dados['AVG(Municipio_Status.renda)'].corr(dados['AVG(Municipio_Status.educacao)'])
correlacao_educacao_renda
# Out:
# np.float64(0.9058425758448345)

# %% [markdown]
# Esse valor em torno de 0,98 significa uma correlação positiva fortíssima entre educação e renda nos seus dados. Isso quer dizer: quanto maior a média de educação, maior tende a ser a média de renda, de forma bem consistente (quase linear).

# %% [markdown]
# #Visualização de Dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_csv('/content/drive/MyDrive/Programaria/Módulo 3 e 4/analise_dados.csv')
dados.head()
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
# ...

# %%
genero_counts = dados['GENERO'].value_counts()
genero_counts
# Out:
# GENERO
# Masculino               3194
# Feminino                1058
# Prefiro não informar      21
# Name: count, dtype: int64

# %%
plt.figure()
plt.bar(height=genero_counts.values, x=genero_counts.index)
plt.title('Quantidade de pessoas por gênero na área de Dados')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.show()

# %%
plt.figure()
sns.countplot(data=dados, x='GENERO', palette='pastel')
plt.title('Quantidade de pessoas por gênero na área de Dados')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.show()
# Out:
# /tmp/ipykernel_53259/3198164885.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dados, x='GENERO', palette='pastel')

# %%
salario_por_idade = dados.groupby('IDADE')['SALARIO'].mean()
salario_por_idade
# Out:
# IDADE
# 18.000000     4230.307692
# 19.000000     4519.590909
# 20.000000     5004.272727
# 20.205479     3536.000000
# 21.000000     4578.737179
# 22.000000     4394.689815
# 23.000000     5602.406897
# 24.000000     6151.622449
# 25.000000     7616.392336
# 26.000000     7700.071174
# 27.000000     8237.429766
# 28.000000     9737.938144
# 29.000000     9554.853147
# 30.000000    10316.412686
# 31.000000    10021.462609
# 31.153517     9646.330882
# 32.000000    10843.197778
# 33.000000    11592.718590
# 34.000000    12294.640212
# 35.000000    12435.845105
# 36.000000    12267.966533
# 37.000000    12613.528357
# 38.000000    13802.724874
# 39.000000    13309.082898
# 40.000000    15028.032721
# 41.000000    13578.880952
# 42.000000    11801.037037
# 43.000000    14349.732278
# 44.000000    14665.770147
# 45.000000    16103.431520
# 46.000000    11913.709677
# 47.000000    11156.031250
# 48.000000    12249.714286
# 49.000000    14556.000000
# 50.000000    15740.010181
# ...

# %%
plt.figure()
plt.plot(salario_por_idade.index, salario_por_idade.values, marker='o', linestyle='--')
plt.xlabel('Idade')
plt.ylabel('Média de salário')
plt.title('Média de salário por idade')
plt.grid(True)
plt.show()

# %%
fig = px.line(salario_por_idade.reset_index(), x='IDADE', y='SALARIO', title='Média de salário por idade', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(15, 5))
plt.scatter(dados['IDADE'], dados['SALARIO'], alpha=0.5)
plt.xlabel('Idade')
plt.ylabel('Salário')
plt.title('Dispersão de salário por idade')
plt.grid(True)
plt.show()

# %%
fig = px.scatter(dados, x='IDADE', y='SALARIO', title='Dispersão de salário por idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
