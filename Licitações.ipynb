# %% [markdown]
# <a href="https://colab.research.google.com/github/ingridcos/Programaria/blob/main/Licita%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MÓDULO 3 - QUESTIONÁRIO

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/licitacoes.csv', encoding='latin1', sep=';')

# %%
display(df)
# Out:
#        Número Licitação  Código UG  \
# 0                 12016     160438
# 1                 12017     160203
# 2                 12017     193002
# 3                 12018     925135
# 4                 12018     110101
# ...                 ...        ...
# 15331         920182018     135023
# 15332         924192017     158274
# 15333         990922018     158139
# 15334         996252018     153035
# 15335         996252018     153035
#
#                                             Nome UG  Código Modalidade Compra  \
# 0         COMANDO 2 BRIGADA DE CAVALARIA MECANIZADA                       -99
# 1           2º BATALHAO DE ENGENHARIA DE CONSTRUCAO                         3
# 2      DEPARTAMENTO NACIONAL DE OBRAS CONT.AS SECAS                         2
# 3                  BANCO CENTRAL DO BRASIL - RECIFE                         6
# 4         GABINETE DA VICE-PRESIDENCIA DA REPUBLICA                         7
# ...

# %%
linhas, colunas = df.shape
print(f"Linhas: {linhas}, Colunas: {colunas}")
# Out:
# Linhas: 15336, Colunas: 17

# %%
df[df['Situação Licitação']=='Encerrado']
# Out:
#        Número Licitação  Código UG  \
# 3                 12018     925135
# 16                12018     130129
# 18                12018     135097
# 19                12018     152140
# 24                12018     153092
# ...                 ...        ...
# 15327         907662018     926130
# 15328         907732018     926130
# 15329         908252018     926130
# 15333         990922018     158139
# 15334         996252018     153035
#
#                                             Nome UG  Código Modalidade Compra  \
# 3                  BANCO CENTRAL DO BRASIL - RECIFE                         6
# 16       SUPERINT.REG.DE DESENV.DA LAV.CACAUEIRA/MT                         6
# 18                                     EMBRAPA CAFE                         7
# 19                    IFB - CAMPUS TAGUATINGA NORTE                         6
# 24                       BIBLIOTECA CENTRAL DA UFPE                         6
# ...

# %%
df['Situação Licitação'].value_counts()
# Out:
# Situação Licitação
# Encerrado                         9016
# Publicado                         3709
# Evento de Resultado de Julgame    1922
# Retificação                        127
# Evento de Alteração Publicad        93
# Evento de Suspensão Publicado       72
# Anulação                            67
# Revogação                           63
# Divulgado                           55
# Evento de Adiamento Publicado       46
# Evento de Retificação Public        45
# Evento de Revogação Publicad        40
# Evento de Alteração de Resul        37
# Evento de Anulação Publicado        18
# Evento de Retificação Divulg         7
# Inválido                             4
# Evento de Habilitação Public         4
# Evento de Alteração Divulgad         4
# Evento de Reabertura de Prazo        4
# Evento de Adiamento Divulgado        3
# Name: count, dtype: int64

# %%
df['Situação Licitação'].nunique()
# Out:
# 20

# %%
df.groupby('Situação Licitação')['Situação Licitação'].nunique()
# Out:
# Situação Licitação
# Anulação                          1
# Divulgado                         1
# Encerrado                         1
# Evento de Adiamento Divulgado     1
# Evento de Adiamento Publicado     1
# Evento de Alteração Divulgad      1
# Evento de Alteração Publicad      1
# Evento de Alteração de Resul      1
# Evento de Anulação Publicado      1
# Evento de Habilitação Public      1
# Evento de Reabertura de Prazo     1
# Evento de Resultado de Julgame    1
# Evento de Retificação Divulg      1
# Evento de Retificação Public      1
# Evento de Revogação Publicad      1
# Evento de Suspensão Publicado     1
# Inválido                          1
# Publicado                         1
# Retificação                       1
# Revogação                         1
# Name: Situação Licitação, dtype: int64

# %% [markdown]
# #MÓDULO 4 - VALORES FALTANTES

# %% [markdown]
# Identifique qual coluna possui valores faltantes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15336 entries, 0 to 15335
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Número Licitação          15336 non-null  int64
#  1   Código UG                 15336 non-null  int64
#  2   Nome UG                   15336 non-null  object
#  3   Código Modalidade Compra  15336 non-null  int64
#  4   Modalidade Compra         15336 non-null  object
#  5   Número Processo           15336 non-null  object
#  6   Objeto                    15336 non-null  object
#  7   Situação Licitação        15336 non-null  object
#  8   Código Órgão Superior     15336 non-null  int64
#  9   Nome Órgão Superior       15336 non-null  object
#  10  Código Órgão              15336 non-null  int64
#  11  Nome Órgão                15336 non-null  object
#  12  UF                        15336 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Número Licitação', 'Código UG', 'Nome UG', 'Código Modalidade Compra',
#        'Modalidade Compra', 'Número Processo', 'Objeto', 'Situação Licitação',
#        'Código Órgão Superior', 'Nome Órgão Superior', 'Código Órgão',
#        'Nome Órgão', 'UF', 'Município', 'Data Resultado Compra',
#        'Data Abertura', 'Valor Licitação'],
#       dtype='object')

# %%
df['Data Abertura']
# Out:
# 0        17/08/2016
# 1               NaN
# 2               NaN
# 3        30/11/2018
# 4               NaN
#             ...
# 15331    26/11/2018
# 15332           NaN
# 15333           NaN
# 15334           NaN
# 15335           NaN
# Name: Data Abertura, Length: 15336, dtype: object

# %% [markdown]
# Identifique o tipo de dados desta coluna

# %%
df.groupby(['Data Abertura'], dropna=False)['Código UG'].nunique()
# Out:
# Data Abertura
# 01/06/2018       1
# 01/10/2018       5
# 01/11/2018      26
# 01/12/2018       1
# 02/04/2018       1
#               ...
# 31/07/2018       1
# 31/08/2018       1
# 31/10/2018      31
# 31/12/2018       6
# NaN           1708
# Name: Código UG, Length: 180, dtype: int64

# %% [markdown]
# Substitua os valores faltantes pelo mesmo formato

# %%
df['Data Abertura'] = df['Data Abertura'].fillna('00/00/0000')

# %%
df.groupby(['Data Abertura'], dropna=False)['Código UG'].nunique()
# Out:
# Data Abertura
# 00/00/0000    1708
# 01/06/2018       1
# 01/10/2018       5
# 01/11/2018      26
# 01/12/2018       1
#               ...
# 31/01/2018       1
# 31/07/2018       1
# 31/08/2018       1
# 31/10/2018      31
# 31/12/2018       6
# Name: Código UG, Length: 180, dtype: int64
